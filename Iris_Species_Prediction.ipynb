# %% [markdown]
# <a href="https://colab.research.google.com/github/SmaranikaManaswini/Iris-Species-Prediction-using-Ensemble-Learning-and-Cross-Validation/blob/main/Iris_Species_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('species',axis=1)
y=df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn=KNeighborsClassifier(n_neighbors=2)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
model_knn.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_svm=SVC(gamma='auto')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
y_pred=model_svm.predict(X_test)

# %%
model_svm.score(X_test,y_test)
# Out:
# 1.0

# %%
#now lets see gridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
Classifier=GridSearchCV((model_svm),
                        {
                            'C':[1,10,20,2],
                            'kernel':['linear','rbf']
                        },cv=5,return_train_score=False)

# %%
Classifier.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 2], 'kernel': ['linear', 'rbf']})

# %%
Classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00398254, 0.00327911, 0.00319829, 0.0034574 , 0.00547824,
#         0.00908322, 0.00934429, 0.00596089]),
#  'std_fit_time': array([0.00113772, 0.00015379, 0.00031876, 0.0002529 , 0.00266529,
#         0.00564962, 0.00514615, 0.00391736]),
#  'mean_score_time': array([0.00358977, 0.00260015, 0.00245104, 0.00250678, 0.00761943,
#         0.00743179, 0.00651217, 0.00796289]),
#  'std_score_time': array([1.52646186e-03, 3.51184996e-04, 1.57427959e-04, 5.59410267e-05,
#         3.03637961e-03, 3.53420716e-03, 4.01062654e-03, 5.83369572e-03]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 2, 2],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf',
#                     'linear', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
# ...

# %%
df2=pd.DataFrame(Classifier.cv_results_)

# %%
df2
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.003983      0.001138         0.003590        0.001526        1
# 1       0.003279      0.000154         0.002600        0.000351        1
# 2       0.003198      0.000319         0.002451        0.000157       10
# 3       0.003457      0.000253         0.002507        0.000056       10
# 4       0.005478      0.002665         0.007619        0.003036       20
# 5       0.009083      0.005650         0.007432        0.003534       20
# 6       0.009344      0.005146         0.006512        0.004011        2
# 7       0.005961      0.003917         0.007963        0.005834        2
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           1.000000
# 1          rbf      {'C': 1, 'kernel': 'rbf'}           1.000000
# 2       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# ...

# %%
df2[['param_C','param_kernel','params','mean_test_score']]
# Out:
#    param_C param_kernel                         params  mean_test_score
# 0        1       linear   {'C': 1, 'kernel': 'linear'}         0.958333
# 1        1          rbf      {'C': 1, 'kernel': 'rbf'}         0.950000
# 2       10       linear  {'C': 10, 'kernel': 'linear'}         0.950000
# 3       10          rbf     {'C': 10, 'kernel': 'rbf'}         0.958333
# 4       20       linear  {'C': 20, 'kernel': 'linear'}         0.950000
# 5       20          rbf     {'C': 20, 'kernel': 'rbf'}         0.950000
# 6        2       linear   {'C': 2, 'kernel': 'linear'}         0.958333
# 7        2          rbf      {'C': 2, 'kernel': 'rbf'}         0.950000

# %%
from sklearn.model_selection import RandomizedSearchCV  #let us try randonmizedSearchCV

# %%
classifier_RCV=RandomizedSearchCV((model_svm),
                                  {
                                      'C':[30,10,20,2],
                                      'kernel':['linear','rbf']
                                  },cv=5,return_train_score=False,n_iter=4)

# %%
classifier_RCV.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [30, 10, 20, 2],
#                                         'kernel': ['linear', 'rbf']})

# %%
result=pd.DataFrame(classifier_RCV.cv_results_)

# %%
result[['param_C','param_kernel','params','mean_test_score']]
# Out:
#    param_C param_kernel                         params  mean_test_score
# 0        2          rbf      {'kernel': 'rbf', 'C': 2}         0.950000
# 1       30       linear  {'kernel': 'linear', 'C': 30}         0.941667
# 2       20          rbf     {'kernel': 'rbf', 'C': 20}         0.950000
# 3       10          rbf     {'kernel': 'rbf', 'C': 10}         0.958333

# %%
#Ensemble Learning(stacking)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)  #splitted the data into 80% training set on which we will apply cross validation,20% of testing data will be used later to test the meta model.

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
base_learners = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svc', SVC(probability=True, kernel='rbf', random_state=42)),
    ('lr', LogisticRegression(max_iter=1000))
]

# %%
meta_learner = LogisticRegression(max_iter=1000)

# %%
stacking_clf = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5
)

# %%
stacking_clf.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr', LogisticRegression(max_iter=1000))],
#                    final_estimator=LogisticRegression(max_iter=1000))

# %%
y_pred = stacking_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    random_state=42
)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
ada_model=AdaBoostClassifier(n_estimators=100,random_state=42)

# %%
ada_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_pred_ada=ada_model.predict(X_test)

# %%
accuracy_ada=accuracy_score(y_test,y_pred_ada)

# %%
accuracy_ada
# Out:
# 0.9333333333333333

# %%
grad_model=GradientBoostingClassifier(n_estimators=100,learning_rate=0.1,random_state=42)

# %%
grad_model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred_grad=grad_model.predict(X_test)

# %%
accuracy_grad=accuracy_score(y_test,y_pred_grad)

# %%
accuracy_grad
# Out:
# 0.9666666666666667

# %%
xgb_model=XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# %%
xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred=xgb_model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9333333333333333
